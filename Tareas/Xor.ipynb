# %%
import numpy as np
from keras.models import Sequential
from keras.layers.core import Dense


training_data = np.array([[0,0],[0,1],[1,0],[1,1]], "float32")
target_data = np.array([[0],[1],[1],[0]], "float32")

model = Sequential()
model.add(Dense(16, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='mean_squared_error',
              optimizer='adam',
              metrics=['binary_accuracy'])

model.fit(training_data, target_data, epochs=40)

scores = model.evaluate(training_data, target_data)
print('-'*100)

print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
print('-'*100)
print("input", training_data)
print('-'*100)
print ("output", model.predict(training_data).round())
# Out:
# 2023-04-06 20:53:06.022332: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/40
# 1/1 [==============================] - 1s 942ms/step - loss: 0.2478 - binary_accuracy: 0.5000
# Epoch 2/40
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2475 - binary_accuracy: 0.2500
# Epoch 3/40
# 1/1 [==============================] - 0s 39ms/step - loss: 0.2471 - binary_accuracy: 0.5000
# Epoch 4/40
# 1/1 [==============================] - 0s 41ms/step - loss: 0.2468 - binary_accuracy: 0.5000
# Epoch 5/40
# 1/1 [==============================] - 0s 32ms/step - loss: 0.2464 - binary_accuracy: 0.5000
# Epoch 6/40
# 1/1 [==============================] - 0s 50ms/step - loss: 0.2460 - binary_accuracy: 0.5000
# Epoch 7/40
# 1/1 [==============================] - 0s 35ms/step - loss: 0.2457 - binary_accuracy: 0.5000
# Epoch 8/40
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2453 - binary_accuracy: 0.5000
# Epoch 9/40
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2450 - binary_accuracy: 0.5000
# Epoch 10/40
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2446 - binary_accuracy: 0.5000
# Epoch 11/40
# 1/1 [==============================] - 0s 27ms/step - loss: 0.2443 - binary_accuracy: 0.5000
# Epoch 12/40
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2439 - binary_accuracy: 0.5000
# Epoch 13/40
# 1/1 [==============================] - 0s 21ms/step - loss: 0.2436 - binary_accuracy: 0.5000
# Epoch 14/40
# 1/1 [==============================] - 0s 22ms/step - loss: 0.2432 - binary_accuracy: 0.5000
# Epoch 15/40
# 1/1 [==============================] - 0s 24ms/step - loss: 0.2429 - binary_accuracy: 0.5000
# Epoch 16/40
# 1/1 [==============================] - 0s 24ms/step - loss: 0.2426 - binary_accuracy: 0.5000
# Epoch 17/40
# 1/1 [==============================] - 0s 22ms/step - loss: 0.2423 - binary_accuracy: 0.5000
# Epoch 18/40
# 1/1 [==============================] - 0s 24ms/step - loss: 0.2420 - binary_accuracy: 0.5000
# Epoch 19/40
# 1/1 [==============================] - 0s 24ms/step - loss: 0.2417 - binary_accuracy: 0.5000
# Epoch 20/40
# 1/1 [==============================] - 0s 25ms/step - loss: 0.2414 - binary_accuracy: 0.5000
# Epoch 21/40
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2411 - binary_accuracy: 0.5000
# Epoch 22/40
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2408 - binary_accuracy: 0.5000
# Epoch 23/40
# 1/1 [==============================] - 0s 44ms/step - loss: 0.2405 - binary_accuracy: 0.5000
# Epoch 24/40
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2401 - binary_accuracy: 0.5000
# Epoch 25/40
# 1/1 [==============================] - 0s 18ms/step - loss: 0.2398 - binary_accuracy: 0.5000
# Epoch 26/40
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2395 - binary_accuracy: 0.5000
# Epoch 27/40
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2392 - binary_accuracy: 0.5000
# Epoch 28/40
# 1/1 [==============================] - 0s 19ms/step - loss: 0.2389 - binary_accuracy: 0.7500
# Epoch 29/40
# 1/1 [==============================] - 0s 23ms/step - loss: 0.2387 - binary_accuracy: 0.7500
# Epoch 30/40
# 1/1 [==============================] - 0s 25ms/step - loss: 0.2384 - binary_accuracy: 0.7500
# Epoch 31/40
# 1/1 [==============================] - 0s 47ms/step - loss: 0.2381 - binary_accuracy: 0.7500
# Epoch 32/40
# 1/1 [==============================] - 0s 33ms/step - loss: 0.2378 - binary_accuracy: 0.7500
# Epoch 33/40
# 1/1 [==============================] - 0s 61ms/step - loss: 0.2375 - binary_accuracy: 1.0000
# Epoch 34/40
# 1/1 [==============================] - 0s 51ms/step - loss: 0.2372 - binary_accuracy: 1.0000
# Epoch 35/40
# 1/1 [==============================] - 0s 38ms/step - loss: 0.2369 - binary_accuracy: 1.0000
# Epoch 36/40
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2367 - binary_accuracy: 1.0000
# Epoch 37/40
# 1/1 [==============================] - 0s 31ms/step - loss: 0.2364 - binary_accuracy: 1.0000
# Epoch 38/40
# 1/1 [==============================] - 0s 39ms/step - loss: 0.2361 - binary_accuracy: 1.0000
# Epoch 39/40
# 1/1 [==============================] - 0s 24ms/step - loss: 0.2358 - binary_accuracy: 1.0000
# Epoch 40/40
# 1/1 [==============================] - 0s 17ms/step - loss: 0.2355 - binary_accuracy: 1.0000
# 1/1 [==============================] - 0s 238ms/step - loss: 0.2352 - binary_accuracy: 1.0000
# ----------------------------------------------------------------------------------------------------
#
# binary_accuracy: 100.00%
# ----------------------------------------------------------------------------------------------------
# input [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# ----------------------------------------------------------------------------------------------------
# 1/1 [==============================] - 0s 176ms/step
# output [[0.]
#  [1.]
#  [1.]
#  [0.]]
